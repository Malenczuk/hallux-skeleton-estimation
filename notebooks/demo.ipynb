# %%
from src.angles import *
from src.skeletonize import *
from src.utils import *

# %load_ext autoreload
# %autoreload 2

# %%
for _, image in sample_images("../data/unet_mask_devel_big_toe_aspect_ratio", 3, seed=2):
    _, fil_pruned = skeletonize(image, visualize=False)
    lines_data = find_lines(fil_pruned.skeleton_longpath)
    visualize_all(image, fil_pruned.skeleton_longpath, lines_data)
