# %%
from src.utils import *
from src.skeletonize import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
for filepath, img in sample_images("../data/unet_mask_devel_big_toe_aspect_ratio/", 5, seed=0):
    _ = skeletonize(img, visualize=True)
# Out:
# /home/malenczuk/anaconda3/envs/scientific/lib/python3.8/site-packages/fil_finder/filfinder2D.py:138: UserWarning: No beam width given. Using 0 pixels.
#   warnings.warn("No beam width given. Using 0 pixels.")
# /home/malenczuk/anaconda3/envs/scientific/lib/python3.8/site-packages/astropy/units/quantity.py:477: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/malenczuk/anaconda3/envs/scientific/lib/python3.8/site-packages/astropy/units/quantity.py:477: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/malenczuk/anaconda3/envs/scientific/lib/python3.8/site-packages/fil_finder/filament.py:326: UserWarning: Graph pruning reached max iterations.
#   warnings.warn("Graph pruning reached max iterations.")
