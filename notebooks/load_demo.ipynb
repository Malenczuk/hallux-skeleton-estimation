# %%
from src.utils import *
# %load_ext autoreload
# %autoreload 2

# %%
img = load_image("../data/unet_mask_devel_big_toe_aspect_ratio/img_0041.png")
plt.imshow(img, cmap="gray")

# %%
for filepath, img in sample_images("../data/unet_mask_devel_big_toe_aspect_ratio", n=5, seed=0):
    plt.imshow(img, cmap="gray")
    plt.title(os.path.basename(filepath))
    plt.show()
